# %% [markdown]
# #String Operations
# 1. string concatenation ( + )
# 2. string repetation ( * )

# %%
#concatenation
s1 = "code" 
s2 = "gnan"
print(s1+s2)
# Out:
# codegnan

# %%
#concatenation
s1 = "code" 
s2 = "gnan" #space
print(s1+" "+ s2)
print(s1 + s1)
print(s1 * 5)
print((s1 +" ")  * 5)
print((s1 +" ") ,(s2 +" ")  * 5)
print((s1 +" ") * 5 ,(s2 +" ")  * 5)
# Out:
# code gnan
# codecode
# codecodecodecodecode
# code code code code code
# code  gnan gnan gnan gnan gnan
# code code code code code  gnan gnan gnan gnan gnan

# %% [markdown]
# #Attende Management

# %%
n = 9
absent = present = 0
for i in range(1,n+1):
    val = int(input(f"enter Roll no:{i} absent:"))
# Out:
# enter Roll no:1 absent: 45
# enter Roll no:2 absent: 66
# enter Roll no:3 absent: 7
# enter Roll no:4 absent: 55
# enter Roll no:5 absent: 66
# enter Roll no:6 absent: 7
# enter Roll no:7 absent: 9
# enter Roll no:8 absent: 8
# enter Roll no:9 absent: 9
